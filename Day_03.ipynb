# %%
data = {"batsman":['virat','rohit','ab'],'bowlers':['steyn','anderson','broad']}

# %%
import pandas as pd

# %%
df = pd.DataFrame(data,index=['a','b','c'])

# %%
df.head()
# Out:
#   batsman   bowlers
# a   virat     steyn
# b   rohit  anderson
# c      ab     broad

# %%
df.columns
# Out:
# Index(['batsman', 'bowlers'], dtype='object')

# %%
df.sample(2)
# Out:
#   batsman   bowlers
# b   rohit  anderson
# c      ab     broad

# %%
print(df.loc['a']['batsman'])
# Out:
# virat

# %%
df.iloc[:2]
# Out:
#   batsman   bowlers
# a   virat     steyn
# b   rohit  anderson

# %%
df1 = pd.DataFrame(data,index=range(10,13))

# %%
df1.head()
# Out:
#    batsman   bowlers
# 10   virat     steyn
# 11   rohit  anderson
# 12      ab     broad

# %%
df.get(10)

# %%
df =  pd.read_csv("/home/labuser/Downloads/IMDB-Movie-Data.csv")
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.count()
# Out:
# Rank                  1000
# Title                 1000
# Genre                 1000
# Description           1000
# Director              1000
# Actors                1000
# Year                  1000
# Runtime (Minutes)     1000
# Rating                1000
# Votes                 1000
# Revenue (Millions)     872
# Metascore              936
# dtype: int64

# %%
df.size
# Out:
# 12000

# %%
df[df.isnull()]
# Out:
#      Rank Title Genre Description Director Actors  Year  Runtime (Minutes)  \
# 0     NaN   NaN   NaN         NaN      NaN    NaN   NaN                NaN
# 1     NaN   NaN   NaN         NaN      NaN    NaN   NaN                NaN
# 2     NaN   NaN   NaN         NaN      NaN    NaN   NaN                NaN
# 3     NaN   NaN   NaN         NaN      NaN    NaN   NaN                NaN
# 4     NaN   NaN   NaN         NaN      NaN    NaN   NaN                NaN
# ..    ...   ...   ...         ...      ...    ...   ...                ...
# 995   NaN   NaN   NaN         NaN      NaN    NaN   NaN                NaN
# 996   NaN   NaN   NaN         NaN      NaN    NaN   NaN                NaN
# 997   NaN   NaN   NaN         NaN      NaN    NaN   NaN                NaN
# 998   NaN   NaN   NaN         NaN      NaN    NaN   NaN                NaN
# 999   NaN   NaN   NaN         NaN      NaN    NaN   NaN                NaN
#
#      Rating  Votes  Revenue (Millions)  Metascore
# ...

# %%
df = pd.read_csv("/home/labuser/Downloads/IMDB-Movie-Data.csv",index_col='Rank')

# %%
df.head(5)
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# 3     Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 4     In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 5     A secret government agency recruits some of th...            David Ayer
#
#                                                  Actors  Year  \
# Rank
# 1     Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# ...

# %%
df.describe()
# Out:
#               Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean   2012.783000         113.172000     6.723200  1.698083e+05
# std       3.205962          18.810908     0.945429  1.887626e+05
# min    2006.000000          66.000000     1.900000  6.100000e+01
# 25%    2010.000000         100.000000     6.200000  3.630900e+04
# 50%    2014.000000         111.000000     6.800000  1.107990e+05
# 75%    2016.000000         123.000000     7.400000  2.399098e+05
# max    2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# 50%             47.985000   59.500000
# 75%            113.715000   72.000000
# max            936.630000  100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               1000 non-null   object
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %%
df['Metascore'].size
# Out:
# 1000

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.drop_duplicates()
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
# ...                       ...                       ...
# 996      Secret in Their Eyes       Crime,Drama,Mystery
# 997           Hostel: Part II                    Horror
# 998    Step Up 2: The Streets       Drama,Music,Romance
# 999              Search Party          Adventure,Comedy
# 1000               Nine Lives     Comedy,Family,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
tdf = df.head(5)

# %%
df=df.append(tdf)
# Out:
# /tmp/ipykernel_1990/202816571.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(tdf)

# %%
df=pd.concat([df,tdf],axis=0)

# %%
df.shape
# Out:
# (1010, 11)

# %%
df = df.drop_duplicates(['Title'],keep='last')

# %%
df.shape
# Out:
# (999, 11)

# %%
df = pd.concat([df,tdf],axis=0)

# %%
df.shape
# Out:
# (1004, 11)

# %%
pd.concat([df,tdf],axis=1).isnull()
# Out:
#       Title  Genre  Description  Director  Actors   Year  Runtime (Minutes)  \
# Rank
# 6     False  False        False     False   False  False              False
# 7     False  False        False     False   False  False              False
# 8     False  False        False     False   False  False              False
# 9     False  False        False     False   False  False              False
# 10    False  False        False     False   False  False              False
# ...     ...    ...          ...       ...     ...    ...                ...
# 1     False  False        False     False   False  False              False
# 2     False  False        False     False   False  False              False
# 3     False  False        False     False   False  False              False
# 4     False  False        False     False   False  False              False
# 5     False  False        False     False   False  False              False
#
# ...

# %%
df.loc[:,['Title','Genre']]
# Out:
#                         Title                       Genre
# Rank
# 6              The Great Wall    Action,Adventure,Fantasy
# 7                  La La Land          Comedy,Drama,Music
# 8                    Mindhorn                      Comedy
# 9          The Lost City of Z  Action,Adventure,Biography
# 10                 Passengers     Adventure,Drama,Romance
# ...                       ...                         ...
# 1     Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 2                  Prometheus    Adventure,Mystery,Sci-Fi
# 3                       Split             Horror,Thriller
# 4                        Sing     Animation,Comedy,Family
# 5               Suicide Squad    Action,Adventure,Fantasy
#
# [1004 rows x 2 columns]

# %%
df.sort_values(['Genre']).head()
# Out:
#                        Title             Genre  \
# Rank
# 581     Kickboxer: Vengeance            Action
# 124     Boyka: Undisputed IV            Action
# 285                 Hercules  Action,Adventure
# 345             Spider-Man 3  Action,Adventure
# 369   The Amazing Spider-Man  Action,Adventure
#
#                                             Description         Director  \
# Rank
# 581          A kick boxer is out to avenge his brother.   John Stockwell
# 124   In the fourth installment of the fighting fran...  Todor Chapkanov
# 285   Having endured his legendary twelve labors, He...     Brett Ratner
# 345   A strange black entity from another world bond...        Sam Raimi
# 369   After Peter Parker is bitten by a genetically ...        Marc Webb
#
#                                                  Actors  Year  \
# Rank
# 581   Dave Bautista, Alain Moussi, Gina Carano, Jean...  2016
# 124   Scott Adkins, Teodora Duhovnikova, Alon Aboutb...  2016
# ...

# %%
df.sort_index().head()
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
#
#                                             Description            Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...          James Gunn
# 1     A group of intergalactic criminals are forced ...          James Gunn
# 2     Following clues to the origin of mankind, a te...        Ridley Scott
# 2     Following clues to the origin of mankind, a te...        Ridley Scott
# 3     Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                                  Actors  Year  \
# Rank
# 1     Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (999, 11)

# %%
df.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.rename(columns={'Title':'TT'},inplace=True)

# %%
df.rename(columns={'TT':'Title'},inplace=True)

# %%
df.tail()
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# 3     Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 4     In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 5     A secret government agency recruits some of th...            David Ayer
#
#                                                  Actors  Year  \
# Rank
# 1     Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# ...

# %%
df.dropna(subset=['Title'],inplace=True)

# %%
df.shape
# Out:
# (999, 11)

# %%
df.columns = [i.upper() for i in df.columns]

# %%
df.columns
# Out:
# Index(['TITLE', 'GENRE', 'DESCRIPTION', 'DIRECTOR', 'ACTORS', 'YEAR',
#        'RUNTIME (MINUTES)', 'RATING', 'VOTES', 'REVENUE (MILLIONS)',
#        'METASCORE'],
#       dtype='object')

# %%
df.reset_index(inplace=True)

# %%
df['METASCORE'].mean()
# Out:
# 59.01069518716577

# %%
df['METASCORE']=df['METASCORE'].fillna(df['METASCORE'].mean())

# %%
df['METASCORE'].isnull().sum()
# Out:
# 0

# %%
df['REVENUE (MILLIONS)']=df['REVENUE (MILLIONS)'].fillna(df['REVENUE (MILLIONS)'].mean())

# %%
df.isna().sum()
# Out:
# Rank                  0
# TITLE                 0
# GENRE                 0
# DESCRIPTION           0
# DIRECTOR              0
# ACTORS                0
# YEAR                  0
# RUNTIME (MINUTES)     0
# RATING                0
# VOTES                 0
# REVENUE (MILLIONS)    0
# METASCORE             0
# dtype: int64

# %%
df['TITLE']=df['TITLE'].mask(df['GENRE'].str.startswith('A'),'ACTION')

# %%
df.head()
# Out:
#    Rank       TITLE                       GENRE  \
# 0     6      ACTION    Action,Adventure,Fantasy
# 1     7  La La Land          Comedy,Drama,Music
# 2     8    Mindhorn                      Comedy
# 3     9      ACTION  Action,Adventure,Biography
# 4    10      ACTION     Adventure,Drama,Romance
#
#                                          DESCRIPTION         DIRECTOR  \
# 0  European mercenaries searching for black powde...      Yimou Zhang
# 1  A jazz pianist falls for an aspiring actress i...  Damien Chazelle
# 2  A has-been actor best known for playing the ti...       Sean Foley
# 3  A true-life drama, centering on British explor...       James Gray
# 4  A spacecraft traveling to a distant colony pla...    Morten Tyldum
#
#                                               ACTORS  YEAR  RUNTIME (MINUTES)  \
# 0      Matt Damon, Tian Jing, Willem Dafoe, Andy Lau  2016                103
# 1  Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....  2016                128
# ...

# %%
df.query('YEAR>2015')
# Out:
#      Rank                 TITLE                       GENRE  \
# 0       6                ACTION    Action,Adventure,Fantasy
# 1       7            La La Land          Comedy,Drama,Music
# 2       8              Mindhorn                      Comedy
# 3       9                ACTION  Action,Adventure,Biography
# 4      10                ACTION     Adventure,Drama,Romance
# ..    ...                   ...                         ...
# 974   981  Miracles from Heaven      Biography,Drama,Family
# 993  1000            Nine Lives       Comedy,Family,Fantasy
# 996     3                 Split             Horror,Thriller
# 997     4                ACTION     Animation,Comedy,Family
# 998     5                ACTION    Action,Adventure,Fantasy
#
#                                            DESCRIPTION              DIRECTOR  \
# 0    European mercenaries searching for black powde...           Yimou Zhang
# 1    A jazz pianist falls for an aspiring actress i...       Damien Chazelle
# ...

# %%
df[df['YEAR'].isin([2015,2016])]['YEAR'].value_counts()
# Out:
# 2016    297
# 2015    127
# Name: YEAR, dtype: int64

# %%
df.apply(lambda x:x['YEAR'],axis=1)
# Out:
# 0      2016
# 1      2016
# 2      2016
# 3      2016
# 4      2016
#        ...
# 994    2014
# 995    2012
# 996    2016
# 997    2016
# 998    2016
# Length: 999, dtype: int64

# %%
df.describe()
# Out:
#               Rank         YEAR  RUNTIME (MINUTES)      RATING         VOTES  \
# count   999.000000   999.000000         999.000000  999.000000  9.990000e+02
# mean    500.760761  2012.782783         113.160160    6.724024  1.698813e+05
# std     288.846302     3.207560          18.816602    0.945543  1.888431e+05
# min       1.000000  2006.000000          66.000000    1.900000  6.100000e+01
# 25%     251.500000  2010.000000         100.000000    6.200000  3.630600e+04
# 50%     501.000000  2014.000000         111.000000    6.800000  1.108250e+05
# 75%     750.500000  2016.000000         123.000000    7.400000  2.400475e+05
# max    1000.000000  2016.000000         191.000000    9.000000  1.791916e+06
#
#        REVENUE (MILLIONS)   METASCORE
# count          999.000000  999.000000
# mean            83.021056   59.010695
# std             96.443829   16.625845
# min              0.000000   11.000000
# 25%             17.415000   48.000000
# 50%             60.440000   59.010695
# ...

# %%
df1 = df.loc[:,['Rank','YEAR']]

# %%
df1.head()
# Out:
#    Rank  YEAR
# 0     6  2016
# 1     7  2016
# 2     8  2016
# 3     9  2016
# 4    10  2016

# %%
df[['Rank','YEAR']]
# Out:
#      Rank  YEAR
# 0       6  2016
# 1       7  2016
# 2       8  2016
# 3       9  2016
# 4      10  2016
# ..    ...   ...
# 994     1  2014
# 995     2  2012
# 996     3  2016
# 997     4  2016
# 998     5  2016
#
# [999 rows x 2 columns]

# %%
df[df['YEAR'].between(2012,2014)]
# Out:
#      Rank                    TITLE                     GENRE  \
# 31     37                   ACTION    Adventure,Drama,Sci-Fi
# 48     54                   ACTION     Action,Crime,Thriller
# 60     66                   ACTION   Action,Adventure,Comedy
# 71     77                   ACTION             Action,Sci-Fi
# 77     83  The Wolf of Wall Street    Biography,Comedy,Crime
# ..    ...                      ...                       ...
# 983   990                    Selma   Biography,Drama,History
# 988   995                Project X                    Comedy
# 992   999                   ACTION          Adventure,Comedy
# 994     1                   ACTION   Action,Adventure,Sci-Fi
# 995     2                   ACTION  Adventure,Mystery,Sci-Fi
#
#                                            DESCRIPTION           DIRECTOR  \
# 31   A team of explorers travel through a wormhole ...  Christopher Nolan
# 48   An ex-hitman comes out of retirement to track ...     Chad Stahelski
# ...

# %%
df.loc[10]
# Out:
# Rank                                                                 16
# TITLE                                                            ACTION
# GENRE                                        Animation,Adventure,Comedy
# DESCRIPTION           The quiet life of a terrier named Max is upend...
# DIRECTOR                                                   Chris Renaud
# ACTORS                Louis C.K., Eric Stonestreet, Kevin Hart, Lake...
# YEAR                                                               2016
# RUNTIME (MINUTES)                                                    87
# RATING                                                              6.6
# VOTES                                                            120259
# REVENUE (MILLIONS)                                               368.31
# METASCORE                                                          61.0
# Name: 10, dtype: object

# %%
df.iloc[0:3]
# Out:
#    Rank       TITLE                     GENRE  \
# 0     6      ACTION  Action,Adventure,Fantasy
# 1     7  La La Land        Comedy,Drama,Music
# 2     8    Mindhorn                    Comedy
#
#                                          DESCRIPTION         DIRECTOR  \
# 0  European mercenaries searching for black powde...      Yimou Zhang
# 1  A jazz pianist falls for an aspiring actress i...  Damien Chazelle
# 2  A has-been actor best known for playing the ti...       Sean Foley
#
#                                               ACTORS  YEAR  RUNTIME (MINUTES)  \
# 0      Matt Damon, Tian Jing, Willem Dafoe, Andy Lau  2016                103
# 1  Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....  2016                128
# 2  Essie Davis, Andrea Riseborough, Julian Barrat...  2016                 89
#
#    RATING   VOTES  REVENUE (MILLIONS)  METASCORE
# 0     6.1   56036           45.130000       42.0
# 1     8.3  258682          151.060000       93.0
# ...

# %%
df[df['YEAR']<2007]
# Out:
#      Rank                             TITLE                       GENRE  \
# 59     65                      The Prestige        Drama,Mystery,Sci-Fi
# 73     79                            ACTION    Action,Adventure,Fantasy
# 94    100                      The Departed        Crime,Drama,Thriller
# 108   114                            ACTION          Action,Fantasy,War
# 159   165                            ACTION   Action,Adventure,Thriller
# 216   222                            ACTION  Animation,Adventure,Comedy
# 225   231                   Pan's Labyrinth           Drama,Fantasy,War
# 227   233                            ACTION      Action,Adventure,Drama
# 240   247                   Children of Men       Drama,Sci-Fi,Thriller
# 291   298             The Devil Wears Prada                Comedy,Drama
# 302   309                            ACTION       Action,Crime,Thriller
# 314   321                           Step Up           Crime,Drama,Music
# ...

# %%
df['YEAR'].describe()
# Out:
# count     999.000000
# mean     2012.782783
# std         3.207560
# min      2006.000000
# 25%      2010.000000
# 50%      2014.000000
# 75%      2016.000000
# max      2016.000000
# Name: YEAR, dtype: float64

# %%
df[(df['DIRECTOR'].str.startswith('A')) & (df['YEAR']<=2007) ]
# Out:
#      Rank                                              TITLE  \
# 240   247                                    Children of Men
# 314   321                                            Step Up
# 480   487                                          Hairspray
# 505   512                                             ACTION
# 587   594                                      She's the Man
# 607   614  The Assassination of Jesse James by the Coward...
# 852   859                                The Hills Have Eyes
# 879   886                                              Babel
# 929   936                                             ACTION
# 985   992                                   Taare Zameen Par
#
#                      GENRE                                        DESCRIPTION  \
# 240  Drama,Sci-Fi,Thriller  In 2027, in a chaotic world in which women hav...
# 314      Crime,Drama,Music  Tyler Gage receives the opportunity of a lifet...
# ...

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
plt.bar(['a','b','c'],[10,20,30],color=['red','yellow'])
plt.show()

# %%
df.columns
# Out:
# Index(['Rank', 'TITLE', 'GENRE', 'DESCRIPTION', 'DIRECTOR', 'ACTORS', 'YEAR',
#        'RUNTIME (MINUTES)', 'RATING', 'VOTES', 'REVENUE (MILLIONS)',
#        'METASCORE'],
#       dtype='object')

# %%
plt.plot([1,2,3,4],[10,15,7,21],color='red')
plt.xlabel("Points")
plt.ylabel("Price")
plt.title("Points VS Price Comparison")
# Out:
# Text(0.5, 1.0, 'Points VS Price Comparison')

# %%
import numpy as  np

# %%
l = [1,2,3,4]
a = np.array(l)

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
import datetime
t = 1632069752
ft = datetime.datetime.utcfromtimestamp(t).strftime('%Y-%m-%d %H:%M:%S')
print(ft)
# Out:
# 2021-09-19 16:42:32

# %%
def solution(N): 
    def sum_of_digits(number): 
        return sum(map(int, str(number))) 
    current_number = N + 1 
    while True: 
        if sum_of_digits(current_number) == sum_of_digits(N): 
            return current_number 
        current_number += 1

# %%
def solution(N): 
    current_number = N + 1 
    while True: 
        if sum(map(int, str(current_number))) == sum(map(int, str(N))): 
            return current_number 
        current_number += 1

# %%
def solution(N): 
    def sum_of_digits(number): 
        return sum() for digit in str(number)]) current_number = N + 1 while True: if sum_of_digits(current_number) == sum_of_digits(N): return current_number current_number += 1

# %%
def solution(N): 
    def sum_of_digits(number): 
        digit_sum = 0 
        while number > 0: 
            return digit_sum 
        current_number = N + 1 
        while True: 
            if sum_of_digits(current_number) == sum_of_digits(N): 
                return current_number 
            current_number += 1
